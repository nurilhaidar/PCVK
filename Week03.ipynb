# %% [markdown]
# <a href="https://colab.research.google.com/github/nurilhaidar/PCVK/blob/main/Week03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('drive')
# Out:
# Mounted at drive

# %%
from google.colab.patches import cv2_imshow
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **PRAKTIKUM**

# %%
print('Merubah tingkat kecerahan citra')
print('-------------------------------')

try:
  brightness = int(input('Masukan Nilai Kecerahan : '))
except ValueError:
  print('Masukkan angka yang benar !')

original = cv.imread('/content/drive/MyDrive/Images/female.tiff')
brightness_image = np.zeros(original.shape, original.dtype)

# Akses Per Piksel
for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      brightness_image[y,x,c] = np.clip(original[y,x,c] + brightness, 0, 255)

# Tanpa menggunakan for loop
# brightness_image = cv.convertScaleAbs(original, beta=brightness)

final_frame = cv.hconcat((original, brightness_image))
cv2_imshow(final_frame)
# Out:
# Merubah tingkat kecerahan citra
# -------------------------------
# Masukan Nilai Kecerahan : 200
# <PIL.Image.Image image mode=RGB size=512x256>

# %% [markdown]
# **TUGAS PRAKTIKUM**

# %%
# INVERSE IMAGE
inverse_image = np.zeros(original.shape, original.dtype)

for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      inverse_image[y,x,c] = np.clip(255 - original[y,x,c], 0, 255)

final_frame_2 = cv.hconcat((original, inverse_image))
cv2_imshow(final_frame_2)
# Out:
# <PIL.Image.Image image mode=RGB size=512x256>

# %%
# CONTRAST IMAGE
try:
  contrast = int(input('Masukan Nilai Kontrast : '))
  brightness_2 = int(input('Masukan Nilai Brightness : '))
except ValueError:
  print('Masukkan angka yang benar !')

contrast_image = np.zeros(original.shape, original.dtype)

for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      contrast_image[y,x,c] = np.clip(contrast * original[y,x,c] + brightness_2, 0, 255)

final_frame_3 = cv.hconcat((original, contrast_image))
cv2_imshow(final_frame_3)
# Out:
# Masukan Nilai Kontrast : 2
# Masukan Nilai Brightness : 50
# <PIL.Image.Image image mode=RGB size=512x256>

# %%
# Logarithmic Brightness
try:
  cons = int(input('Masukkan Nilai Kecerahan : '))
except ValueError:
  print('Masukkan angka yang benar !')

log_image = np.zeros(original.shape, original.dtype)

for x in range(original.shape[2]):
      log_image[:,:,x] = np.clip(cons * np.log(1 + original[:,:,x]), 0, 255)

final_frame_4 = cv.hconcat((original, log_image))
cv2_imshow(final_frame_4)
# Out:
# Masukkan Nilai Kecerahan : 50
# <PIL.Image.Image image mode=RGB size=512x256>

# %%
# Averaging
ktp = cv.imread('/content/drive/MyDrive/Images/KTP.jpeg')
img = cv.cvtColor(ktp ,cv.COLOR_BGR2RGB)

avg_gray = np.mean(img, axis=2)

plt.subplot(1, 2, 1)
plt.imshow(avg_gray, cmap='gray')

# %%
# Lightness
light_gray = np.mean(([np.max(img, axis=2), np.min(img, axis=2)]), axis=0)

plt.imshow(light_gray, cmap='gray')

# %%
# Luminance
r, g, b = cv.split(img)

lum_gray = 0.21 * r + 0.72 * g + 0.07 * b

plt.imshow(lum_gray, cmap='gray')

# %%
# NOMOR 5

r, g, b = cv.split(img)

test = 0.21 * r + 0.72 * g
test = test.astype(np.uint8)

test_blue = cv.merge([test, test, b])

plt.imshow(test_blue, cmap='gray')
