# %% [markdown]
# <a href="https://colab.research.google.com/github/nurilhaidar/PCVK/blob/main/Week02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

img = cv.imread('/content/drive/MyDrive/Images/kitten01.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/Images/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img_4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512, 1024))
plt.imshow(img_4)

# %%
img_5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB), 0)
plt.imshow(img_5)

# %%
black_img = np.zeros(shape=(512,512,3), dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(384,0), pt2=(510,150), color=(0,255,0), thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(200,200), pt2=(300,300) ,color=(0,0,255), thickness=10)
plt.imshow(black_img)

# %%
cv.circle(black_img, center=(100,100), radius=(50), color=(255,0,0), thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img, pt1=(0,0), pt2=(512,512), color=(255,255,255), thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='Hello', org=(10,500), fontFace=font, fontScale=4, color=(255,255,0), thickness=2, lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img_2 = np.zeros(shape=(512,512,3), dtype=np.int32)
plt.imshow(black_img_2)

# %%
vertices = np.array([[100,300], [200,200], [400,300], [200,400]], dtype=np.int32)
pts = vertices.reshape((-1,1,2))
cv.polylines(black_img_2, [pts], isClosed=True, color=(255,0,0), thickness=5)
plt.imshow(black_img_2)

# %% [markdown]
# **PERTANYAAN**

# %% [markdown]
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
# - Dengan menggunakan matplotlib kita dapat menampilkan gambar langsung dari python tanpa harus menggunakan aplikasi pihak ketiga jika tidak menggunakan matplotlib, kemudian pada matplotlib juga menyediakan ukuran gambar untuk mempermudah mengalisis gambar
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16 dan int32?
# - perbedaan anatara keduanya adalah terletak pada pemrosesan dari black image yang dibuat, jika menggunakan int16 maka akan lebih cepat pemrosesannya daripada int32
# 3. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode berikut
# - cv2_imshow digunakan untuk menampilkan gambar yang didapatkan dari modul yang telah disediakan oleh google colab
# 4. Apakah kegunaan “skimage import io” pada potongan kode soal nomor 3
# - io digunakan untuk membaca berbagai format gambar yang akan dibaca

# %% [markdown]
# **TUGAS**

# %% [markdown]
# 1.Dengan menggunakan figsize, perhatikan apakah ukuran image pixelnya juga berubah?
# - Tidak berubah, karena yang berubah hanya ukuran dari matplotlib nya saja

# %%
plt.figure(figsize=(3, 2))
plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))

# %% [markdown]
# 2. Tampilkan image dalam channel Red-Blue dan Green-Blue saja!

# %%
red_blue = img.copy()
red_blue[:, :, 1] = 0
plt.imshow(red_blue)

# %%
green_blue = img.copy()
green_blue[:,:,2] = 0
plt.imshow(green_blue)

# %% [markdown]
# 3. Tampilkan image baris ke 20-115, kolom 25-120!

# %%
plt.imshow(img[20:115, 25:120])

# %% [markdown]
# 4. Tampilkan image baris ke 5-30, semua kolom, channel Red saja!

# %%
img_red = img.copy()
img_red[:,:,2] = 0
plt.imshow(img_red[5:30])

# %% [markdown]
# 5. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image.
# disarankan menggunakan bilangan acak/random!

# %%
bg = np.zeros(shape=(512,512,3), dtype=np.int16)
cv.rectangle(bg, pt1=(123,34), pt2=(54,122), color=(255,245), thickness=2)
cv.rectangle(bg, pt1=(34,123), pt2=(23,245), color=(224,233), thickness=2)
cv.rectangle(bg, pt1=(233,85), pt2=(134,167), color=(123,178), thickness=2)
cv.rectangle(bg, pt1=(156,21), pt2=(56,234), color=(56,155), thickness=2)
cv.rectangle(bg, pt1=(87,34), pt2=(23,22), color=(57,143), thickness=2)
plt.imshow(bg)

# %% [markdown]
# 5. Tampilkan image dengan posisi terbalik!

# %%
plt.imshow(cv.cvtColor(cv.flip(img,0), cv.COLOR_BGR2RGB))
